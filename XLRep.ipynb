# %% [markdown]
# <a href="https://colab.research.google.com/github/GabeMaldonado/JupyterNotebooks/blob/master/XLRep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
Image('/home.PNG')

# %%
Image('/project_tab.PNG')

# %%
Image('/data_tab.PNG')

# %%
Image('/schedule.PNG')

# %%
Image('/XLReporter_Web.PNG')

# %%
Image('/monthlly_power.PNG')
